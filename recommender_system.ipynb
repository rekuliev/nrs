# %% [markdown]
# <h1 align='center'>Recommender system</h1>
# <h2 align='center'>Introduction to similarity learning and recommendation systems</h2>
# <h3 align='center'>Training work</h3>

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# <h2 align='center'>Part 1</h1>
# <h3 align='center'>Preparing data</h2>
#
# Primarily, let's take a look at the data:

# %%
raw_data = pd.read_csv("dataset/netflix_titles.csv")
raw_data.head()
# Out:
#   show_id     type  title           director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie   7:19  Jorge Michel Grau
# 2      s3    Movie  23:59       Gilbert Chan
# 3      s4    Movie      9        Shane Acker
# 4      s5    Movie     21     Robert Luketic
#
#                                                 cast        country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...         Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...         Mexico
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...      Singapore
# 3  Elijah Wood, John C. Reilly, Jennifer Connelly...  United States
# 4  Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...  United States
#
#           date_added  release_year rating   duration  \
# 0    August 14, 2020          2020  TV-MA  4 Seasons
# 1  December 23, 2016          2016  TV-MA     93 min
# 2  December 20, 2018          2011      R     78 min
# 3  November 16, 2017          2009  PG-13     80 min
# 4    January 1, 2020          2008  PG-13    123 min
#
#                                            listed_in  \
# 0  International TV Shows, TV Dramas, TV Sci-Fi &...
# 1                       Dramas, International Movies
# 2                Horror Movies, International Movies
# 3  Action & Adventure, Independent Movies, Sci-Fi...
# 4                                             Dramas
#
#                                          description
# 0  In a future where the elite inhabit an island ...
# 1  After a devastating earthquake hits Mexico Cit...
# 2  When an army recruit is found dead, his fellow...
# 3  In a postapocalyptic world, rag-doll robots hi...
# 4  A brilliant group of students become card-coun...

# %% [markdown]
# So, we should clear up some data features and leave the most relevant and easy-to-evaluate
#
# The case is rather problematic, there is no assessment of features' weight without users' action information. In this way the task should be reformulated to leaving the most unambiguous features
#
# What about uncertain data, "date_added", "release_year", "duration" should be highlighted. That data can't unambiguous show what user would prefer, but it should be noticed that the features can be participated in evaluation with a collaborative and approaches. "show_id" features in calculation won't be participate, so we can drop it
#
# And now we can transform our dataframe:

# %%
input_data = raw_data.drop(['show_id', 'title', 'date_added', 'release_year', 'duration',], axis=1)
input_data.index = raw_data.title
input_data.head()
# Out:
#           type           director  \
# title
# 3%     TV Show                NaN
# 7:19     Movie  Jorge Michel Grau
# 23:59    Movie       Gilbert Chan
# 9        Movie        Shane Acker
# 21       Movie     Robert Luketic
#
#                                                     cast        country  \
# title
# 3%     João Miguel, Bianca Comparato, Michel Gomes, R...         Brazil
# 7:19   Demián Bichir, Héctor Bonilla, Oscar Serrano, ...         Mexico
# 23:59  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...      Singapore
# 9      Elijah Wood, John C. Reilly, Jennifer Connelly...  United States
# 21     Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...  United States
#
#       rating                                          listed_in  \
# title
# 3%     TV-MA  International TV Shows, TV Dramas, TV Sci-Fi &...
# 7:19   TV-MA                       Dramas, International Movies
# 23:59      R                Horror Movies, International Movies
# 9      PG-13  Action & Adventure, Independent Movies, Sci-Fi...
# 21     PG-13                                             Dramas
#
#                                              description
# title
# 3%     In a future where the elite inhabit an island ...
# 7:19   After a devastating earthquake hits Mexico Cit...
# 23:59  When an army recruit is found dead, his fellow...
# 9      In a postapocalyptic world, rag-doll robots hi...
# 21     A brilliant group of students become card-coun...

# %% [markdown]
# Also we can notice that in that dataframe movies and tv shows are mixed, necessity for output tv show during movie analysis is arguabled and vauge. So it should be separated:

# %%
movie = input_data.query('type == "Movie"')
movie.head()
# Out:
#         type           director  \
# title
# 7:19   Movie  Jorge Michel Grau
# 23:59  Movie       Gilbert Chan
# 9      Movie        Shane Acker
# 21     Movie     Robert Luketic
# 122    Movie    Yasir Al Yasiri
#
#                                                     cast        country  \
# title
# 7:19   Demián Bichir, Héctor Bonilla, Oscar Serrano, ...         Mexico
# 23:59  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...      Singapore
# 9      Elijah Wood, John C. Reilly, Jennifer Connelly...  United States
# 21     Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...  United States
# 122    Amina Khalil, Ahmed Dawood, Tarek Lotfy, Ahmed...          Egypt
#
#       rating                                          listed_in  \
# title
# 7:19   TV-MA                       Dramas, International Movies
# 23:59      R                Horror Movies, International Movies
# 9      PG-13  Action & Adventure, Independent Movies, Sci-Fi...
# 21     PG-13                                             Dramas
# 122    TV-MA                Horror Movies, International Movies
#
#                                              description
# title
# 7:19   After a devastating earthquake hits Mexico Cit...
# 23:59  When an army recruit is found dead, his fellow...
# 9      In a postapocalyptic world, rag-doll robots hi...
# 21     A brilliant group of students become card-coun...
# 122    After an awful accident, a couple admitted to ...

# %%
tv_show = input_data.query('type == "TV Show"')
tv_show.head()
# Out:
#            type              director  \
# title
# 3%      TV Show                   NaN
# 46      TV Show           Serdar Akar
# 1983    TV Show                   NaN
# 1994    TV Show  Diego Enrique Osorno
# Feb-09  TV Show                   NaN
#
#                                                      cast  \
# title
# 3%      João Miguel, Bianca Comparato, Michel Gomes, R...
# 46      Erdal Beşikçioğlu, Yasemin Allen, Melis Birkan...
# 1983    Robert Więckiewicz, Maciej Musiał, Michalina O...
# 1994                                                  NaN
# Feb-09  Shahd El Yaseen, Shaila Sabt, Hala, Hanadi Al-...
#
#                       country rating  \
# title
# 3%                     Brazil  TV-MA
# 46                     Turkey  TV-MA
# 1983    Poland, United States  TV-MA
# 1994                   Mexico  TV-MA
# Feb-09                    NaN  TV-14
#
#                                                 listed_in  \
# title
# 3%      International TV Shows, TV Dramas, TV Sci-Fi &...
# 46        International TV Shows, TV Dramas, TV Mysteries
# 1983    Crime TV Shows, International TV Shows, TV Dramas
# 1994    Crime TV Shows, Docuseries, International TV S...
# Feb-09                  International TV Shows, TV Dramas
#
#                                               description
# title
# 3%      In a future where the elite inhabit an island ...
# 46      A genetics professor experiments with a treatm...
# 1983    In this dark alt-history thriller, a naïve law...
# 1994    Archival video and new interviews examine Mexi...
# Feb-09  As a psychology professor faces Alzheimer's, h...

# %% [markdown]
# <h2 align='center'>Part 2</h2>
# <h3 align='center'>Approaches for similarity evaluation</h3>

# %% [markdown]
# <h3 align='center'>2.1. Similarity measure</h3>
